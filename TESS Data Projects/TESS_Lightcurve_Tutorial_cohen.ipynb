# %% [markdown]
# ### Tutorial for L98-59 Lightcurve Analysis from NASA TESS
# ##### followed by Cohen Panneri

# %% [markdown]
# **Imports:**

# %%
# %pip install lightkurve

# %%
import lightkurve as lk
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 1. Accessing Data Products
# #####    - full frame image: search_tesscut()
# #####    - target pixel file: search_targetpixelfile()
# #####    - pre-made lightcurve file: search_lightcurve()

# %%
search_ffi = lk.search_tesscut('L98-59')
search_tpf = lk.search_targetpixelfile('L98-59')
search_lcf = lk.search_lightcurve('L98-59')

# %%
search_ffi
# Out:
# SearchResult containing 28 data products.
#
#  #     mission     year  author exptime target_name distance
#                                    s                 arcsec
# --- -------------- ---- ------- ------- ----------- --------
#   0 TESS Sector 05 2018 TESScut    1426      L98-59      0.0
#   1 TESS Sector 01 2018 TESScut    1426      L98-59      0.0
#   2 TESS Sector 02 2018 TESScut    1426      L98-59      0.0
#   3 TESS Sector 10 2019 TESScut    1426      L98-59      0.0
#   4 TESS Sector 11 2019 TESScut    1426      L98-59      0.0
#   5 TESS Sector 12 2019 TESScut    1426      L98-59      0.0
#   6 TESS Sector 08 2019 TESScut    1426      L98-59      0.0
#   7 TESS Sector 09 2019 TESScut    1426      L98-59      0.0
#   8 TESS Sector 32 2020 TESScut     475      L98-59      0.0
#   9 TESS Sector 28 2020 TESScut     475      L98-59      0.0
#  10 TESS Sector 29 2020 TESScut     475      L98-59      0.0
#  11 TESS Sector 39 2021 TESScut     475      L98-59      0.0
# ...

# %% [markdown]
# *Output:* SearchResult containing 28 data products.
#
# <table id="table5470132880">
# <thead><tr><th>#</th><th>mission</th><th>year</th><th>author</th><th>exptime</th><th>target_name</th><th>distance</th></tr></thead>
# <thead><tr><th></th><th></th><th></th><th></th><th>s</th><th></th><th>arcsec</th></tr></thead>
# <tr><td>0</td><td>TESS Sector 05</td><td>2018</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>1426</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>1</td><td>TESS Sector 01</td><td>2018</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>1426</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>2</td><td>TESS Sector 02</td><td>2018</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>1426</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>3</td><td>TESS Sector 10</td><td>2019</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>1426</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>4</td><td>TESS Sector 11</td><td>2019</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>1426</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>5</td><td>TESS Sector 12</td><td>2019</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>1426</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>6</td><td>TESS Sector 08</td><td>2019</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>1426</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>7</td><td>TESS Sector 09</td><td>2019</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>1426</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>8</td><td>TESS Sector 32</td><td>2020</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>475</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>9</td><td>TESS Sector 28</td><td>2020</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>475</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>10</td><td>TESS Sector 29</td><td>2020</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>475</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>11</td><td>TESS Sector 39</td><td>2021</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>475</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>12</td><td>TESS Sector 36</td><td>2021</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>475</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>13</td><td>TESS Sector 37</td><td>2021</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>475</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>14</td><td>TESS Sector 38</td><td>2021</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>475</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>15</td><td>TESS Sector 35</td><td>2021</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>475</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>16</td><td>TESS Sector 61</td><td>2023</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>158</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>17</td><td>TESS Sector 65</td><td>2023</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>158</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>18</td><td>TESS Sector 69</td><td>2023</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>158</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>19</td><td>TESS Sector 62</td><td>2023</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>158</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>20</td><td>TESS Sector 63</td><td>2023</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>158</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>21</td><td>TESS Sector 64</td><td>2023</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>158</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>22</td><td>TESS Sector 87</td><td>2024</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>158</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>23</td><td>TESS Sector 96</td><td>2025</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>158</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>24</td><td>TESS Sector 88</td><td>2025</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>158</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>25</td><td>TESS Sector 89</td><td>2025</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>158</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>26</td><td>TESS Sector 90</td><td>2025</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>158</td><td>L98-59</td><td>0.0</td></tr>
# <tr><td>27</td><td>TESS Sector 98</td><td>2025</td><td><a href='https://mast.stsci.edu/tesscut/'>TESScut</a></td><td>158</td><td>L98-59</td><td>0.0</td></tr>
# </table>

# %%
search_tpf
# Out:
# SearchResult containing 68 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 02 2018      SPOC     120   307210830      0.0
#   1 TESS Sector 05 2018      SPOC     120   307210830      0.0
#   2 TESS Sector 08 2019      SPOC     120   307210830      0.0
#   3 TESS Sector 09 2019      SPOC     120   307210830      0.0
#   4 TESS Sector 10 2019      SPOC     120   307210830      0.0
#   5 TESS Sector 11 2019      SPOC     120   307210830      0.0
#   6 TESS Sector 12 2019      SPOC     120   307210830      0.0
#   7 TESS Sector 28 2020      SPOC      20   307210830      0.0
#   8 TESS Sector 29 2020      SPOC      20   307210830      0.0
#   9 TESS Sector 32 2020      SPOC      20   307210830      0.0
#  10 TESS Sector 28 2020      SPOC     120   307210830      0.0
# ...

# %% [markdown]
# *Output:* SearchResult containing 68 data products.
#
# <table id="table5477930128">
# <thead><tr><th>#</th><th>mission</th><th>year</th><th>author</th><th>exptime</th><th>target_name</th><th>distance</th></tr></thead>
# <thead><tr><th></th><th></th><th></th><th></th><th>s</th><th></th><th>arcsec</th></tr></thead>
# <tr><td>0</td><td>TESS Sector 02</td><td>2018</td><td><a href='https://heasarc.gsfc.nasa.gov/docs/tess/data-handling.html'>SPOC</a></td><td>120</td><td>307210830</td><td>0.0</td></tr>
# <tr><td
td><td>2025</td><td><a href='https://heasarc.gsfc.nasa.gov/docs/tess/data-handling.html'>SPOC</a></td><td>120</td><td>307210830</td><td>0.0</td></tr>
# <tr><td>23</td><td>TESS Sector 89</td><td>2025</td><td><a href='https://heasarc.gsfc.nasa.gov/docs/tess/data-handling.html'>SPOC</a></td><td>120</td><td>307210830</td><td>0.0</td></tr>
# <tr><td>24</td><td>TESS Sector 90</td><td>2025</td><td><a href='https://heasarc.gsfc.nasa.gov/docs/tess/data-handling.html'>SPOC</a></td><td>120</td><td>307210830</td><td>0.0</td></tr>
# <tr><td>25</td><td>TESS Sector 96</td><td>2025</td><td><a href='https://heasarc.gsfc.nasa.gov/docs/tess/data-handling.html'>SPOC</a></td><td>120</td><td>307210830</td><td>0.0</td></tr>
# <tr><td>26</td><td>TESS Sector 98</td><td>2025</td><td><a href='https://heasarc.gsfc.nasa.gov/docs/tess/data-handling.html'>SPOC</a></td><td>120</td><td>307210830</td><td>0.0</td></tr>
# </table>
#
# .
# .
# .
# .

# %%
lcf = search_lcf_refined.download_all()

# %%
lcf
# Out:
# LightCurveCollection of 27 objects:
#     0: <TessLightCurve LABEL="TIC 307210830" SECTOR=2 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     1: <TessLightCurve LABEL="TIC 307210830" SECTOR=5 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     2: <TessLightCurve LABEL="TIC 307210830" SECTOR=8 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     3: <TessLightCurve LABEL="TIC 307210830" SECTOR=9 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     4: <TessLightCurve LABEL="TIC 307210830" SECTOR=10 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     5: <TessLightCurve LABEL="TIC 307210830" SECTOR=11 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     6: <TessLightCurve LABEL="TIC 307210830" SECTOR=12 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     7: <TessLightCurve LABEL="TIC 307210830" SECTOR=28 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     8: <TessLightCurve LABEL="TIC 307210830" SECTOR=29 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     9: <TessLightCurve LABEL="TIC 307210830" SECTOR=32 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
# ...

# %% [markdown]
# Downloaded collection: LightCurveCollection of 27 objects:
#
#     0: TessLightCurve LABEL="TIC 307210830" SECTOR=2 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     1: TessLightCurve LABEL="TIC 307210830" SECTOR=5 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     2: TessLightCurve LABEL="TIC 307210830" SECTOR=8 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     3: TessLightCurve LABEL="TIC 307210830" SECTOR=9 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     4: TessLightCurve LABEL="TIC 307210830" SECTOR=10 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     5: TessLightCurve LABEL="TIC 307210830" SECTOR=11 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     6: TessLightCurve LABEL="TIC 307210830" SECTOR=12 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     7: TessLightCurve LABEL="TIC 307210830" SECTOR=28 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     8: TessLightCurve LABEL="TIC 307210830" SECTOR=29 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     9: TessLightCurve LABEL="TIC 307210830" SECTOR=32 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     10: TessLightCurve LABEL="TIC 307210830" SECTOR=35 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     11: TessLightCurve LABEL="TIC 307210830" SECTOR=36 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     12: TessLightCurve LABEL="TIC 307210830" SECTOR=37 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     13: TessLightCurve LABEL="TIC 307210830" SECTOR=38 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     14: TessLightCurve LABEL="TIC 307210830" SECTOR=39 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     15: TessLightCurve LABEL="TIC 307210830" SECTOR=61 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     16: TessLightCurve LABEL="TIC 307210830" SECTOR=62 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     17: TessLightCurve LABEL="TIC 307210830" SECTOR=63 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     18: TessLightCurve LABEL="TIC 307210830" SECTOR=64 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     19: TessLightCurve LABEL="TIC 307210830" SECTOR=65 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     20: TessLightCurve LABEL="TIC 307210830" SECTOR=69 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     21: TessLightCurve LABEL="TIC 307210830" SECTOR=87 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     22: TessLightCurve LABEL="TIC 307210830" SECTOR=88 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     23: TessLightCurve LABEL="TIC 307210830" SECTOR=89 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     24: TessLightCurve LABEL="TIC 307210830" SECTOR=90 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     25: TessLightCurve LABEL="TIC 307210830" SECTOR=96 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     26: TessLightCurve LABEL="TIC 307210830" SECTOR=98 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>

# %% [markdown]
# .
# .
# .
# .

# %% [markdown]
# *To acces the data in from a specific file, use a dictionary command. This is for sector 2 data.*

# %%
lcf[0]
# Out:
# <TessLightCurve length=18300 LABEL="TIC 307210830" SECTOR=2 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#        time             flux      ...   pos_corr1      pos_corr2
#                     electron / s  ...      pix            pix
#        Time           float32     ...    float32        float32
# ------------------ -------------- ... -------------- --------------
# 1354.1074113410245  2.4635420e+04 ...  3.1294446e-02  1.5483069e-01
# 1354.1088002024744  2.4656008e+04 ...  4.3172963e-02  1.4587776e-01
#  1354.110189063866  2.4635619e+04 ...  6.0803384e-02  1.3428329e-01
# 1354.1129667867635  2.4621027e+04 ...  3.7734102e-02  1.2694269e-01
# 1354.1143556482134  2.4617400e+04 ...  7.8965843e-02  1.5301819e-01
# 1354.1157445097215  2.4630531e+04 ...  7.2042428e-02  1.4030553e-01
#  1354.117133371171  2.4625502e+04 ...  6.8586096e-02  1.3917884e-01
#  1354.118522232678  2.4619252e+04 ...  6.0448773e-02  1.3230386e-01
# 1354.1199110941275  2.4591127e+04 ...  6.4667158e-02  1.3584568e-01
# ...

# %% [markdown]
# *Output:* <div><i>TessLightCurve length=18300 LABEL=&quot;TIC 307210830&quot; SECTOR=2 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux</i>
# <table id="table4427843600" class="table-striped table-bordered table-condensed">
# <thead><tr><th>time</th><th>flux</th><th>flux_err</th><th>timecorr</th><th>cadenceno</th><th>centroid_col</th><th>centroid_row</th><th>sap_flux</th><th>sap_flux_err</th><th>sap_bkg</th><th>sap_bkg_err</th><th>pdcsap_flux</th><th>pdcsap_flux_err</th><th>quality</th><th>psf_centr1</th><th>psf_centr1_err</th><th>psf_centr2</th><th>psf_centr2_err</th><th>mom_centr1</th><th>mom_centr1_err</th><th>mom_centr2</th><th>mom_centr2_err</th><th>pos_corr1</th><th>pos_corr2</th></tr></thead>
# <thead><tr><th></th><th>electron / s</th><th>electron / s</th><th>d</th><th></th><th>pix</th><th>pix</th><th>electron / s</th><th>electron / s</th><th>electron / s</th><th>electron / s</th><th>electron / s</th><th>electron / s</th><th></th><th>pix</th><th>pix</th><th>pix</th><th>pix</th><th>pix</th><th>pix</th><th>pix</th><th>pix</th><th>pix</th><th>pix</th></tr></thead>
# <thead><tr><th>Time</th><th>float32</th><th>float32</th><th>float32</th><th>int32</th><th>float64</th><th>float64</th><th>float32</th><th>float32</th><th>float32</th><th>float32</th><th>float32</th><th>float32</th><th>int32</th><th>float64</th><th>float32</th><th>float64</th><th>float32</th><th>float64</th><th>float32</th><th>float64</th><th>float32</th><th>float32</th><th>float32</th></tr></thead>
# <tr><td>1354.1074113410245</td><td>2.4635420e+04</td><td>1.8856627e+01</td><td>-8.0586493e-04</td><td>91190</td><td>664.04462</td><td>338.97644</td><td>2.3127123e+04</td><td>1.7658133e+01</td><td>1.8465968e+03</td><td>5.2003989e+00</td><td>2.4635420e+04</td><td>1.8856627e+01</td><td>0</td><td>———</td><td>———</td><td>———</td><td>———</td><td>664.04462</td><td>6.2346959e-04</td><td>338.97644</td><td>6.9568102e-04</td><td>3.1294446e-02</td><td>1.5483069e-01</td></tr>
# <tr><td>1354.1088002024744</td><td>2.4656008e+04</td><td>1.8861403e+01</td><td>-8.0589182e-04</td><td>91191</td><td>664.05609</td><td>338.96900</td><td>2.3150639e+04</td><td>1.7662607e+01</td><td>1.8428802e+03</td><td>5.1911125e+00</td><td>2.4656008e+04</td><td>1.8861403e+01</td><td>0</td><td>———</td><td>———</td><td>———</td><td>———</td><td>664
+00</td><td>———</td><td>———</td><td>1000000000000000</td><td>———</td><td>———</td><td>———</td><td>———</td><td>664.02862</td><td>6.5425027e-04</td><td>338.81318</td><td>7.3958829e-04</td><td>1.3605391e-02</td><td>-2.5300540e-02</td></tr>
# <tr><td>1381.5125760342053</td><td>———</td><td>———</td><td>-1.1858977e-03</td><td>110922</td><td>664.01887</td><td>338.81982</td><td>2.3105682e+04</td><td>1.8324867e+01</td><td>2.9604985e+03</td><td>6.2097011e+00</td><td>———</td><td>———</td><td>1000000000000000</td><td>———</td><td>———</td><td>———</td><td>———</td><td>664.01887</td><td>6.5310486e-04</td><td>338.81982</td><td>7.3841790e-04</td><td>3.2073301e-03</td><td>-1.8903004e-02</td></tr>
# </table></div>
# .
# .
# .
# .

# %% [markdown]
# Switching between SAP and PDCSAP(adjusted for long-term trends):

# %%
pdcsap = lcf[0].pdcsap_flux

sapflux = lcf[0].sap_flux

# %% [markdown]
# And plotting

# %%
ax = lcf[0].plot(column='sap_flux', normalize=True, label="SAP");
lcf[0].plot(ax=ax, column='pdcsap_flux', normalize=True, label="PDCSAP");

# %% [markdown]
# *Output:*
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. Manipulating the Lightcurve
# #####    - flatten(): Remove long term trends using a Savitzky–Golay filter
# #####    - remove_outliers(): Remove outliers using simple sigma clipping
# #####    - remove_nans(): Remove infinite or NaN values (these can occur during thruster firings)
# #####    - fold(): Fold the data at a particular period
# #####    - bin(): Reduce the time resolution of the array, taking the average value in each bin.

# %% [markdown]
# Plot and Title:

# %%
ax = lcf[0].plot()
ax.set_title("PDCSAP light curve of  L 98-59")
# Out:
# Text(0.5, 1.0, 'PDCSAP light curve of  L 98-59')

# %% [markdown]
# *Output:*
#
# Text(0.5, 1.0, 'PDCSAP light curve of  L 98-59')
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Flatten, Fold, and Bin the graph:

# %%
lcf[0].flatten(window_length=401).fold(period=3.690621).bin(time_bin_size=0.01).plot();

# %% [markdown]
# *Output:*
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 4. Creating a new lightcurve with ffi data
# #####    - create a 10x10 pixel cutout
# #####    - define and apature mask to filter out irrelevent light

# %%
ffi_data = search_ffi[2].download(cutout_size=10)
ffi_data.plot()
# Out:
# <Axes: title={'center': 'Target ID: L98-59, Cadence: 0'}, xlabel='Pixel Column Number', ylabel='Pixel Row Number'>

# %%
target_mask = ffi_data.create_threshold_mask(threshold=15, reference_pixel='center')
n_target_pixels = target_mask.sum()
n_target_pixels
# Out:
# np.int64(9)

# %%
ffi_data.plot(aperture_mask=target_mask, mask_color='r');

# %%
ffi_lc = ffi_data.to_lightcurve(aperture_mask=target_mask)

# %%
ffi_lc
# Out:
# <TessLightCurve length=1196 LABEL="" SECTOR=2>
#        time              flux           flux_err      ... cadenceno quality
#                      electron / s     electron / s    ...
#        Time            float32          float32       ...   int64    int32
# ------------------ --------------- ------------------ ... --------- -------
# 1354.1355100037465 20954.431640625  3.968478202819824 ...         0       0
# 1354.1563430385859    20953.640625 3.9688515663146973 ...         1       0
#  1354.177176075171  20948.37890625 3.9678900241851807 ...         2       0
# 1354.1980091135024  20953.16796875 3.9682953357696533 ...         3       0
#  1354.218842153522  20949.62109375 3.9680519104003906 ...         4       0
#  1354.239675195171 20950.841796875 3.9680023193359375 ...         5       0
#  1354.260508238421    20944.640625 3.9673573970794678 ...         6       0
# 1354.2813412832716  20952.73046875 3.9680874347686768 ...         7       0
# ...

# %%
ffi_lc.plot(label="SAP FFI")
# Out:
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
ax = lcf[0].plot(column='pdcsap_flux', normalize=True, label="PDCSAP");
ffi_lc.plot(ax=ax, normalize=True, label="SAP FFI")
# Out:
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>
